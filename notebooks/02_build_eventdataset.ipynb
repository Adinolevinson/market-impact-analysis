# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

# %%
import pandas as pd
from reusable_code.process_all_events import process_all_events

# %%
events = pd.read_csv("../data/processed/tesla_events.csv")

company_data = pd.read_csv("../data/raw/TSLA_stock_2019_2026.csv")

benchmark_data = pd.read_csv("../data/raw/SPY_stock_2019_2026.csv")

# %%
from pathlib import Path

print(Path.cwd())
# Out:
# c:\Users\adino\Documents\Projects\market-impact-analysis\notebooks

# %%
import os

print(os.listdir("../data/processed/tesla_events.csv"))
print(os.listdir("../data/processed"))
print(os.listdir("../data/processed/events"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 import os
#       2
# ----> 3 print(os.listdir("../data/processed/tesla_events.csv"))
#       4 print(os.listdir("../data/processed"))
#       5 print(os.listdir("../data/processed/events"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../data/processed/tesla_events.csv'

# %%
import os

print(os.listdir("../data"))
print(os.listdir("../data/processed"))
print(os.listdir("../data/processed/events"))
# Out:
# ['processed', 'raw']
# ['events']
# ['tesla_events.csv']

# %%
events = pd.read_csv("../data/processed/events/tesla_events.csv")

company_data = pd.read_csv("../data/raw/TSLA_stock_2019_2026.csv")

benchmark_data = pd.read_csv("../data/raw/SPY_stock_2019_2026.csv")

# %%
event_dataset = process_all_events(
    events,
    company_data,
    benchmark_data
)
# Out:
# C:\Users\adino\Documents\Projects\market-impact-analysis\reusable_code\event_window.py:9: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   events_data["event_date"] = pd.to_datetime(
# C:\Users\adino\Documents\Projects\market-impact-analysis\reusable_code\event_window.py:9: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   events_data["event_date"] = pd.to_datetime(
# C:\Users\adino\Documents\Projects\market-impact-analysis\reusable_code\event_window.py:9: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   events_data["event_date"] = pd.to_datetime(
# ...

# %%
event_dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   event_id               138 non-null    str
#  1   event_name             138 non-null    str
#  2   event_type             138 non-null    str
#  3   event_date             138 non-null    datetime64[us]
#  4   day                    138 non-null    int64
#  5   Date                   138 non-null    datetime64[us]
#  6   Close                  138 non-null    float64
#  7   return_from_day_0      138 non-null    float64
#  8   SPY_Close              138 non-null    float64
#  9   SPY_return_from_day_0  138 non-null    float64
#  10  abnormal_return        138 non-null    float64
# dtypes: datetime64[us](2), float64(5), int64(1), str(3)
# memory usage: 12.0 KB

# %%
event_dataset.head(20)
# Out:
#     event_id        event_name event_type event_date  day       Date  \
# 0   TSLA_001  Q4 2022 Earnings   Earnings 2023-01-25    0 2023-01-24
# 1   TSLA_001  Q4 2022 Earnings   Earnings 2023-01-25    1 2023-01-25
# 2   TSLA_001  Q4 2022 Earnings   Earnings 2023-01-25    2 2023-01-26
# 3   TSLA_001  Q4 2022 Earnings   Earnings 2023-01-25    3 2023-01-27
# 4   TSLA_001  Q4 2022 Earnings   Earnings 2023-01-25    4 2023-01-30
# 5   TSLA_001  Q4 2022 Earnings   Earnings 2023-01-25    5 2023-01-31
# 6   TSLA_002  Q1 2023 Earnings   Earnings 2023-04-19    0 2023-04-18
# 7   TSLA_002  Q1 2023 Earnings   Earnings 2023-04-19    1 2023-04-19
# 8   TSLA_002  Q1 2023 Earnings   Earnings 2023-04-19    2 2023-04-20
# 9   TSLA_002  Q1 2023 Earnings   Earnings 2023-04-19    3 2023-04-21
# 10  TSLA_002  Q1 2023 Earnings   Earnings 2023-04-19    4 2023-04-24
# 11  TSLA_002  Q1 2023 Earnings   Earnings 2023-04-19    5 2023-04-25
# 12  TSLA_003  Q4 2023 Earnings   Earnings 2024-01-24    0 2024-01-23
# ...

# %%
event_dataset.groupby("event_id").size()
# Out:
# event_id
# TSLA_001    6
# TSLA_002    6
# TSLA_003    6
# TSLA_004    6
# TSLA_005    6
# TSLA_006    6
# TSLA_007    6
# TSLA_008    6
# TSLA_009    6
# TSLA_010    6
# TSLA_011    6
# TSLA_012    6
# TSLA_013    6
# TSLA_014    6
# TSLA_015    6
# TSLA_016    6
# TSLA_017    6
# TSLA_018    6
# TSLA_019    6
# TSLA_020    6
# TSLA_021    6
# TSLA_022    6
# TSLA_023    6
# dtype: int64

# %%
event_dataset["event_id"].nunique()
# Out:
# 23

# %%
len(events)
# Out:
# 23

# %%
event_dataset.to_csv(
    "../data/processed/tesla_event_dataset.csv",
    index=False
)
