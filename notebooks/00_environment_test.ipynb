# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

from reusable_code.stock_data import download_stock_data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import yfinance as yf

print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("scikit-learn:", sklearn.__version__)
print("yfinance:", yf.__version__)
print("Environment is working correctly.")
# Out:
# pandas: 3.0.5
# numpy: 2.5.1
# scikit-learn: 1.9.0
# yfinance: 1.5.2
# Environment is working correctly.

# %%
tesla_data = download_stock_data(
    ticker="TSLA",
    start_date="2024-01-01",
    end_date="2025-01-01",
)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tesla_data
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2024-01-02  248.419998  248.419998  251.250000  244.410004  250.080002
# 2024-01-03  238.449997  238.449997  245.679993  236.320007  244.979996
# 2024-01-04  237.929993  237.929993  242.699997  237.729996  239.250000
# 2024-01-05  237.490005  237.490005  240.119995  234.899994  236.860001
# 2024-01-08  240.449997  240.449997  241.250000  235.300003  236.139999
# ...                ...         ...         ...         ...         ...
# 2024-12-24  462.279999  462.279999  462.779999  435.140015  435.899994
# 2024-12-26  454.130005  454.130005  465.329987  451.019989  465.160004
# 2024-12-27  431.660004  431.660004  450.000000  426.500000  449.519989
# 2024-12-30  417.410004  417.410004  427.000000  415.750000  419.399994
# 2024-12-31  403.839996  403.839996  427.929993  402.540009  423.790009
#
# Price          Volume
# ...

# %%
head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 head()
#
# NameError: name 'head' is not defined

# %%
tesla_data.head()
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2024-01-02  248.419998  248.419998  251.250000  244.410004  250.080002
# 2024-01-03  238.449997  238.449997  245.679993  236.320007  244.979996
# 2024-01-04  237.929993  237.929993  242.699997  237.729996  239.250000
# 2024-01-05  237.490005  237.490005  240.119995  234.899994  236.860001
# 2024-01-08  240.449997  240.449997  241.250000  235.300003  236.139999
#
# Price          Volume
# Ticker           TSLA
# Date
# 2024-01-02  104654200
# 2024-01-03  121082600
# 2024-01-04  102629300
# 2024-01-05   92488900
# 2024-01-08   85166600

# %%
tesla_data.shape
# Out:
# (252, 6)

# %%
tesla_data.columns
# Out:
# MultiIndex([('Adj Close', 'TSLA'),
#             (    'Close', 'TSLA'),
#             (     'High', 'TSLA'),
#             (      'Low', 'TSLA'),
#             (     'Open', 'TSLA'),
#             (   'Volume', 'TSLA')],
#            names=['Price', 'Ticker'])

# %%
tesla_data.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 252 entries, 2024-01-02 to 2024-12-31
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, TSLA)  252 non-null    float64
#  1   (Close, TSLA)      252 non-null    float64
#  2   (High, TSLA)       252 non-null    float64
#  3   (Low, TSLA)        252 non-null    float64
#  4   (Open, TSLA)       252 non-null    float64
#  5   (Volume, TSLA)     252 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 13.8 KB

# %%
tesla_data.describe()
# Out:
# Price    Adj Close       Close        High         Low        Open  \
# Ticker        TSLA        TSLA        TSLA        TSLA        TSLA
# count   252.000000  252.000000  252.000000  252.000000  252.000000
# mean    230.614961  230.614961  235.587103  225.492976  230.580715
# std      70.989891   70.989891   73.203948   68.410065   71.064782
# min     142.050003  142.050003  144.440002  138.800003  140.559998
# 25%     180.004997  180.004997  184.504997  176.980000  181.950001
# 50%     210.695000  210.695000  216.005005  207.654999  212.070000
# 75%     248.619999  248.619999  251.972496  242.507504  247.590004
# max     479.859985  479.859985  488.540009  457.510010  475.899994
#
# Price         Volume
# Ticker          TSLA
# count   2.520000e+02
# mean    9.483947e+07
# std     3.334343e+07
# min     3.716760e+07
# 25%     7.171112e+07
# 50%     8.723310e+07
# 75%     1.101399e+08
# max     2.438697e+08

# %%
tesla_data["Close"].plot(
    figsize=(12, 6),
    title="Tesla Closing Price During 2024",
)
plt.xlabel("Date")
plt.ylabel("Closing price")
plt.show()

# %%
tesla_data.to_csv("../data/raw/tesla_2024.csv")
